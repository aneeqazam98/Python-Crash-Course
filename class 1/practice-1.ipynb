# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print ("Aneeq Azam")
# Out:
# Aneeq Azam

# %%
age = 17
print (age)
# Out:
# 17

# %%
boolean = True
boolean1= False
print (boolean)
# Out:
# True

# %%
print(boolean)
# Out:
# True

# %%
person_1 = "Aneeq"
person_2 = "Azam"
print ("this is a good boy",person_1 , "\n",person_2)
# Out:
# this is a good boy Aneeq
#  Azam

# %%
city_1 = "Karachi"  # define city_1 before using it
print(city_1, end="    !")
# Out:
# Karachi    !

# %%
print("2026", "04", "03", sep="/")
# Out:
# 2026/04/03

# %%
print("A", end="-")
print("B")
# Out:
# A-B

# %%
print ("a","b","c", sep="+", end="!")
# Out:
# a+b+c!
