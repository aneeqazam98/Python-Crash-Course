# %% [markdown]
# # Inputs

# %%
# input 

name = "Ali"
print(name)
# Out:
# Ali

# %%
nametwo = input()
print(nametwo)
# Out:
# aneeq

# %%
age = input()
print(age)
print(type(age))

age = input()
Age = int(age)
print(Age)
print(type(Age))
# Out:
# 12
# <class 'str'>
# 12
# <class 'int'>
